# %%
import sys
sys.path.insert(1, '../functions')
import fractals
import matplotlib.pyplot as plt

# %%
# Barnsley fern
x_coords, y_coords = fractals.BarnsleyFern()

plt.figure(figsize=(1,2))
plt.scatter(x_coords, y_coords, s=0.001, color='k', marker='.', facecolor='k')
plt.axis('off')
plt.savefig('../images/barnsley_fern.png', dpi=400)
plt.show();

# %%
# Serpienski triangle
rows = fractals.SierpinskiTriangle()
plt.figure()#figsize=(1,2))
plt.matshow(rows, cmap=plt.cm.binary)
plt.axis('off')
plt.savefig('../images/serpienski_triangle.png', dpi=400)
plt.show();
